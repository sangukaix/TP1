# %%
import pandas as pd

df = pd.read_stata(
    "data/nsch/nsch_2024e_topical.dta",
    convert_categoricals=False
)

df
# Out:
#           height  fipsst stratum      hhid formtype  totkids_r  tenure  \
# 0            NaN      48       1  24000016       T3          3       2
# 1            NaN      48       1  24000017       T1          1       2
# 2            NaN      47       1  24000044       T1          2       1
# 3            NaN      13      2A  24000054       T1          2       2
# 4            NaN      39       1  24000057       T1          2       1
# ...          ...     ...     ...       ...      ...        ...     ...
# 51370        NaN      55       1  24374938       T1          2       1
# 51371  129.53999       6       1  24374940       T2          2       1
# 51372  152.39999      10       1  24374956       T3          1       1
# 51373  137.16000      25       1  24374958       T2          2       1
# 51374  154.94000      17       1  24374977       T3          1       1
#
#        hhlanguage  sc_age_years  sc_sex  ...  hhcount_if  higrade  \
# ...

# %%
import pandas as pd

# NSCH 데이터 불러오기
df = pd.read_stata(
    "nsch_2024_topical.do",
    convert_categoricals=False
)

# 데이터 크기
print("데이터 크기:", df.shape)

# 앞부분 확인
display(df.head(20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # NSCH 데이터 불러오기
# ----> 4 df = pd.read_stata(
#       5     "nsch_2024_topical.do",
#       6     convert_categoricals=False
#       7 )
#       9 # 데이터 크기
#      10 print("데이터 크기:", df.shape)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\stata.py:2113, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2110     return reader
#    2112 with reader:
# -> 2113     return reader.read()
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\stata.py:1687, in StataReader.read(self, nrows, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals)
# ...
